# %% [markdown]
# <a href="https://colab.research.google.com/github/guilleib227/Big-Data-Colab-UCN-/blob/main/Analisis_Kmeans.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sb
from sklearn.cluster import KMeans
from sklearn.metrics import pairwise_distances_argmin_min
 
# %matplotlib inline
from mpl_toolkits.mplot3d import Axes3D
plt.rcParams['figure.figsize'] = (16, 16)
plt.style.use('ggplot')

# %%
dataframe = pd.read_csv(r"Diabetes1.csv",sep=";")
dataframe.head()
# Out:
#    Number of times pregnant  Plasma glucose concentration  \
# 0                         6                           148
# 1                         1                            85
# 2                         8                           183
# 3                         1                            89
# 4                         0                           137
#
#    Diastolic blood pressure  Triceps skinfold thickness  2-Hour serum insulin  \
# 0                        72                          35                     0
# 1                        66                          29                     0
# 2                        64                           0                     0
# 3                        66                          23                    94
# 4                        40                          35                   168
#
#    Body mass index  Diabetes pedigree  Age  target
# 0              336                627   50       1
# ...

# %%
dataframe.describe()
# Out:
#        Number of times pregnant  Plasma glucose concentration  \
# count                768.000000                    768.000000
# mean                   3.845052                    120.894531
# std                    3.369578                     31.972618
# min                    0.000000                      0.000000
# 25%                    1.000000                     99.000000
# 50%                    3.000000                    117.000000
# 75%                    6.000000                    140.250000
# max                   17.000000                    199.000000
#
#        Diastolic blood pressure  Triceps skinfold thickness  \
# count                768.000000                  768.000000
# mean                  69.105469                   20.536458
# std                   19.355807                   15.952218
# min                    0.000000                    0.000000
# 25%                   62.000000                    0.000000
# ...

# %%
dataframe.drop(['target'],1).hist()
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   """Entry point for launching an IPython kernel.

# %%
sb.pairplot(dataframe.dropna(),hue='target',size=4,vars=["Number of times pregnant","Plasma glucose concentration","Diastolic blood pressure"],kind='scatter')
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/axisgrid.py:2076: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
sb.pairplot(dataframe.dropna(),hue='target',size=4,vars=["Triceps skinfold thickness","Body mass index"],kind='scatter')
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/axisgrid.py:2076: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
sb.pairplot(dataframe.dropna(),hue='target',size=4,vars=["2-Hour serum insulin","Diabetes pedigree","Age"],kind='scatter')
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/axisgrid.py:2076: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)
